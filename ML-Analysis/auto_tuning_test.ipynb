# %%
import pandas as pd
import numpy as np
from scipy import stats

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, LSTM

gpu_devices = tf.config.experimental.list_physical_devices("GPU")
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
def create_data(X,Y):
    time_step=128;
    x_data, y_data = [], []

    for i in range(0,X.size-time_step,1):
        #x_data
        tmp = X.iloc[i:(i+time_step)]
        x_data.append(tmp)
        #y_data
        labels = Y[i:(i+time_step)]
        mode = stats.mode(labels)[0][0]
        if mode == 2 or mode == 4:
            y_data.append(1)
        if mode == 3 or mode == 5:
            y_data.append(0)
        
    return np.array(x_data), np.array(y_data).reshape(-1,1)

# %%
def data():
    df = pd.read_csv('../focus-detection/gsr_record.csv',header=0)
    df = df.set_index('state')
    df = df.drop([1])
    
    df_train = df.copy()
    df_train = df_train.drop([4,5])
    x_train, y_train = create_data(df_train['gsr'],df_train.index.to_list())
    
    df_test = df.copy()
    df_test = df_test.drop([2,3])
    x_test, y_test = create_data(df_test['gsr'],df_test.index.to_list())
    
    x_train = x_train.astype('float32')
    x_train -= x_train.mean(axis=0)
    x_train /= x_train.std(axis=0)
    
    x_test = x_test.astype('float32')
    x_test -= x_test.mean(axis=0)
    x_test /= x_test.std(axis=0)
    
    
    x_train = np.reshape(x_train,[x_train.shape[0],x_train.shape[1],1])
    x_test = np.reshape(x_test,[x_test.shape[0],x_test.shape[1],1])
    
    return x_train, y_train, x_test, y_test

# %%
def model(x_train, y_train, x_test, y_test):
    model = Sequential()
    model.add(LSTM({{choice([8,16,32])}}, input_shape=(x_train.shape[1],1),return_sequences=True))
    model.add(Dropout({{uniform(0,1)}}))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['acc'])
    model.fit(x_train,
              y_train,
              epochs={{choice([16,32,64])}},
              batch_size={{choice([32,64,128])}},
              validation_data=(x_test,y_test),
              shuffle=False)
    val_loss, val_acc = model.evaluate(x_test, y_test, verbose=0)
    return {'loss': -val_acc, 'status': STATUS_OK, 'model': model}

# %%
if __name__ == "__main__":
    best_run, best_model = optim.minimize(model=model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          trials=Trials(),
                                          functions=[create_data],
                                         notebook_name='ml_and_tuning')

    
    x_train, y_train, x_test, y_test = data()
    val_loss, val_acc = best_model.evaluate(x_test, y_test)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from scipy import stats
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow import keras
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Activation, Dropout, LSTM
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'LSTM': hp.choice('LSTM', [8,16,32]),
#         'Dropout': hp.uniform('Dropout', 0,1),
#         'epochs': hp.choice('epochs', [16,32,64]),
#         'batch_size': hp.choice('batch_size', [32,64,128]),
#     }
#
# >>> Functions
#   1: def create_data(X,Y):
#   2:     time_step=128;
#   3:     x_data, y_data = [], []
#   4:
#   5:     for i in range(0,X.size-time_step,1):
#   6:         #x_data
#   7:         tmp = X.iloc[i:(i+time_step)]
#   8:         x_data.append(tmp)
#   9:         #y_data
#  10:         labels = Y[i:(i+time_step)]
#  11:         mode = stats.mode(labels)[0][0]
#  12:         if mode == 2 or mode == 4:
#  13:             y_data.append(1)
#  14:         if mode == 3 or mode == 5:
#  15:             y_data.append(0)
#  16:
#  17:     return np.array(x_data), np.array(y_data).reshape(-1,1)
#  18:
#  19:
# >>> Data
#   1:
#   2: df = pd.read_csv('./gsr_record.csv',header=0)
#   3: df = df.set_index('state')
#   4: df = df.drop([1])
#   5: df_train = df.copy()
#   6: df_train = df_train.drop([4,5])
#   7: x_train, y_train = create_data(df_train['gsr'],df_train.index.to_list())
#   8:
#   9: df_test = df.copy()
#  10: df_test = df_test.drop([2,3])
#  11: x_test, y_test = create_data(df_test['gsr'],df_test.index.to_list())
#  12:
#  13: x_train = x_train.astype('float32')
#  14: x_train -= x_train.mean(axis=0)
#  15: x_train /= x_train.std(axis=0)
#  16:
#  17: x_test = x_test.astype('float32')
#  18: x_test -= x_test.mean(axis=0)
#  19: x_test /= x_test.std(axis=0)
#  20:
#  21:
#  22: x_train = np.reshape(x_train,[x_train.shape[0],x_train.shape[1],1])
#  23: x_test = np.reshape(x_test,[x_test.shape[0],x_test.shape[1],1])
#  24:
#  25:
#  26:
#  27:
# >>> Resulting replaced keras model:
#
#   1: def keras_fmin_fnct(space):
#   2:
#   3:     model = Sequential()
#   4:     model.add(LSTM(space['LSTM'], input_shape=(x_train.shape[1],1),return_sequences=True))
#   5:     model.add(Dropout(space['Dropout']))
#   6:     model.add(Dense(1, activation='sigmoid'))
#   7:
#   8:     model.compile(loss='binary_crossentropy',
#   9:                   optimizer='adam',
#  10:                   metrics=['acc'])
#  11:     model.fit(x_train,
#  12:               y_train,
#  13:               epochs=space['epochs'],
#  14:               batch_size=space['batch_size'],
#  15:               validation_data=(x_test,y_test),
#  16:               shuffle=False)
#  17:     val_loss, val_acc = model.evaluate(x_test, y_test, verbose=0)
#  18:     return {'loss': -val_acc, 'status': STATUS_OK, 'model': model}
#  19:
# Epoch 1/64
#  1/10 [==>...........................]
#  - ETA: 20s - loss: 0.7775 - acc: 0.3645
#
# 10/10 [==============================]
#  - 3s 53ms/step - loss: 0.7289 - acc: 0.4642 - val_loss: 0.6970 - val_acc: 0.4634
#
# Epoch 2/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7485 - acc: 0.4642
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.7174 - acc: 0.5009 - val_loss: 0.6964 - val_acc: 0.4587
#
# Epoch 3/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7392 - acc: 0.4724
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.7139 - acc: 0.5023 - val_loss: 0.6959 - val_acc: 0.4544
#
# Epoch 4/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7374 - acc: 0.4764
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.7130 - acc: 0.5018 - val_loss: 0.6954 - val_acc: 0.4533
#
# Epoch 5/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7348 - acc: 0.4893
#
# 10/10 [==============================]
#  - 0s 8ms/step - loss: 0.7116 - acc: 0.5061 - val_loss: 0.6949 - val_acc: 0.4532
#
# Epoch 6/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7245 - acc: 0.5109
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.7084 - acc: 0.5085 - val_loss: 0.6945 - val_acc: 0.4687
#
# Epoch 7/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7246 - acc: 0.5134
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.7089 - acc: 0.5082 - val_loss: 0.6942 - val_acc: 0.4837
#
# Epoch 8/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7183 - acc: 0.5300
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.7077 - acc: 0.5088 - val_loss: 0.6939 - val_acc: 0.4751
#
# Epoch 9/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.7126 - acc: 0.5457
#
# 10/10 [==============================]
#  - ETA: 0s - loss: 0.7068 - acc: 0.5128
#
# 10/10 [==============================]
#  - 0s 12ms/step - loss: 0.7062 - acc: 0.5117 - val_loss: 0.6936 - val_acc: 0.4762
#
# Epoch 10/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.
#
# 10/10 [==============================]
#  - 0s 11ms/step - loss: 0.6863 - acc: 0.5715 - val_loss: 0.6884 - val_acc: 0.5249
#
# Epoch 56/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6358 - acc: 0.6846
#
# 10/10 [==============================]
#  - 0s 11ms/step - loss: 0.6865 - acc: 0.5723 - val_loss: 0.6882 - val_acc: 0.5255
#
# Epoch 57/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6332 - acc: 0.6978
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6848 - acc: 0.5773 - val_loss: 0.6881 - val_acc: 0.5262
#
# Epoch 58/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6335 - acc: 0.6968
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6846 - acc: 0.5800 - val_loss: 0.6879 - val_acc: 0.5266
#
# Epoch 59/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6342 - acc: 0.7059
#
# 10/10 [==============================]
#  - ETA: 0s - loss: 0.6848 - acc: 0.5845
#
# 10/10 [==============================]
#  - 0s 13ms/step - loss: 0.6848 - acc: 0.5803 - val_loss: 0.6877 - val_acc: 0.5279
#
# Epoch 60/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6344 - acc: 0.7031
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.6838 - acc: 0.5820 - val_loss: 0.6875 - val_acc: 0.5289
#
# Epoch 61/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6311 - acc: 0.7155
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.6832 - acc: 0.5854 - val_loss: 0.6873 - val_acc: 0.5297
#
# Epoch 62/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6313 - acc: 0.7197
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.6827 - acc: 0.5879 - val_loss: 0.6871 - val_acc: 0.5308
#
# Epoch 63/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6309 - acc: 0.7177
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6825 - acc: 0.5925 - val_loss: 0.6869 - val_acc: 0.5321
#
# Epoch 64/64
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6307 - acc: 0.7194
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.6821 - acc: 0.5924 - val_loss: 0.6866 - val_acc: 0.5327
#
# Epoch 1/16
# 1/5 [=====>........................]
#  - ETA: 3s - loss: 0.6827 - acc: 0.5699
#
# 5/5 [==============================]
#  - 1s 90ms/step - loss: 0.6943 - acc: 0.5141 - val_loss: 0.6962 - val_acc: 0.5452
#
# Epoch 2/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6690 - acc: 0.6387
#
# 5/5 [==============================]
#  - 0s 12ms/step - loss: 0.6878 - acc: 0.5566 - val_loss: 0.6961 - val_acc: 0.5337
#
# Epoch 3/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6647 - acc: 0.6641
#
# 5/5 [==============================]
#  - 0s 12ms/step - loss: 0.6866 - acc: 0.5634 - val_loss: 0.6960 - val_acc: 0.5318
#
# Epoch 4/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6602 - acc: 0.6879
#
# 5/5 [==============================]
#  - 0s 12ms/step - loss: 0.6858 - acc: 0.5649 - val_loss: 0.6959 - val_acc: 0.5281
#
# Epoch 5/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6569 - acc: 0.7043
#
# 5/5 [==============================]
#  - 0s 12ms/step - loss: 0.6848 - acc: 0.5709 - val_loss: 0.6958 - val_acc: 0.5250
#
# Epoch 6/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6542 - acc: 0.7186
#
# 5/5 [==============================]
#  - 0s 12ms/step - loss: 0.6850 - acc: 0.5678 - val_loss: 0.6957 - val_acc: 0.5245
#
# Epoch 7/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6514 - acc: 0.7321
#
# 5/5 [==============================]
#  - 0s 13ms/step - loss: 0.6846 - acc: 0.5673 - val_loss: 0.6956 - val_acc: 0.5235
#
# Epoch 8/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6481 - acc: 0.7520
#
# 5/5 [==============================]
#  - 0s 13ms/step - loss: 0.6843 - acc: 0.5688 - val_loss: 0.6955 - val_acc: 0.5237
#
# Epoch 9/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6454 - acc: 0.7631
#
# 5/5 [==============================]
#  - 0s 13ms/step - loss: 0.6841 - acc: 0.5667 - val_loss: 0.6955 - val_acc: 0.5242
#
# Epoch 10/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6427 - acc: 0.7749
#
# 5/5 [==============================]
#  - 0s 13ms/step - loss: 0.6841 - acc: 0.5674 - val_loss: 0.6955 - val_acc: 0.5246
#
# Epoch 11/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6411 - acc: 0.7855
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6847 - acc: 0.5669 - val_loss: 0.6956 - val_acc: 0.5243
#
# Epoch 12/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6378 - acc: 0.7952
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6939 - acc: 0.5538 - val_loss: 0.6979 - val_acc: 0.5185
#
# Epoch 20/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6274 - acc: 0.7991
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6943 - acc: 0.5586 - val_loss: 0.6983 - val_acc: 0.5186
#
# Epoch 21/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6252 - acc: 0.8077
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6945 - acc: 0.5610 - val_loss: 0.6985 - val_acc: 0.5189
#
# Epoch 22/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6239 - acc: 0.8127
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6941 - acc: 0.5651 - val_loss: 0.6986 - val_acc: 0.5190
#
# Epoch 23/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6225 - acc: 0.8203
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6941 - acc: 0.5680 - val_loss: 0.6986 - val_acc: 0.5191
#
# Epoch 24/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6221 - acc: 0.8281
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6944 - acc: 0.5706 - val_loss: 0.6985 - val_acc: 0.5190
#
# Epoch 25/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6212 - acc: 0.8295
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6941 - acc: 0.5703 - val_loss: 0.6984 - val_acc: 0.5192
#
# Epoch 26/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6208 - acc: 0.8309
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6943 - acc: 0.5722 - val_loss: 0.6982 - val_acc: 0.5198
#
# Epoch 27/32
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6193 - acc: 0.8434
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6931 - acc: 0.5773 - val_loss: 0.6981 - val_acc: 0.5200
#
# ...
#  - ETA: 0s - loss: 0.6392 - acc: 0.7659
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6936 - acc: 0.5966 - val_loss: 0.6930 - val_acc: 0.5255
#
# Epoch 18/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6371 - acc: 0.7657
#
# 10/10 [==============================]
#  - 0s 11ms/step - loss: 0.6925 - acc: 0.5986 - val_loss: 0.6926 - val_acc: 0.5252
#
# Epoch 19/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6376 - acc: 0.7714
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6926 - acc: 0.6035 - val_loss: 0.6922 - val_acc: 0.5255
#
# Epoch 20/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6365 - acc: 0.7795
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6914 - acc: 0.6088 - val_loss: 0.6918 - val_acc: 0.5249
#
# Epoch 21/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6330 - acc: 0.7919
#
# 10/10 [==============================]
#  - 0s 11ms/step - loss: 0.6894 - acc: 0.6156 - val_loss: 0.6913 - val_acc: 0.5259
#
# Epoch 22/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6329 - acc: 0.7957
#
# 10/10 [==============================]
#  - ETA: 0s - loss: 0.6895 - acc: 0.6254
#
# 10/10 [==============================]
#  - 0s 12ms/step - loss: 0.6890 - acc: 0.6180 - val_loss: 0.6908 - val_acc: 0.5270
#
# Epoch 23/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6309 - acc: 0.8055
#
#  9/10 [==========================>...]
#  - ETA: 0s - loss: 0.6885 - acc: 0.6393
#
# 10/10 [==============================]
#  - 0s 14ms/step - loss: 0.6876 - acc: 0.6221 - val_loss: 0.6903 - val_acc: 0.5283
#
# Epoch 24/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6298 - acc: 0.8097
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6865 - acc: 0.6263 - val_loss: 0.6897 - val_acc: 0.5290
#
# Epoch 25/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6289 - acc: 0.8110
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6852 - acc: 0.6284 - val_loss: 0.6891 - val_acc: 0.5308
#
# Epoch 26/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6283 - acc: 0.8197
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.6841 - acc: 0.6345 - val_loss: 0.6885 - val_acc: 0.5324
#
# Epoch 27/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6271 - acc: 0.8236
#
# 10/10 [==============================]
#  - 0s 9ms/step - loss: 0.6830 - acc: 0.6389 - val_loss: 0.6879 - val_acc: 0.5346
#
# Epoch 28/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6282 - acc: 0.8159
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6831 - acc: 0.6359 - val_loss: 0.6872 - val_acc: 0.5364
#
# Epoch 29/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6252 - acc: 0.8300
# 10/10 [==============================]
#  - 0s 11ms/step - loss: 0.6806 - acc: 0.6428 - val_loss: 0.6865 - val_acc: 0.5379
#
# Epoch 30/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6242 - acc: 0.8323
#
# 10/10 [==============================]
#  - 0s 11ms/step - loss: 0.6791 - acc: 0.6462 - val_loss: 0.6858 - val_acc: 0.5397
#
# Epoch 31/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6238 - acc: 0.8351
#
# 10/10 [==============================]
#  - 0s 12ms/step - loss: 0.6773 - acc: 0.6508 - val_loss: 0.6852 - val_acc: 0.5410
#
# Epoch 32/32
#  1/10 [==>...........................]
#  - ETA: 0s - loss: 0.6245 - acc: 0.8335
#
# 10/10 [==============================]
#  - 0s 10ms/step - loss: 0.6765 - acc: 0.6519 - val_loss: 0.6847 - val_acc: 0.5420
#
# Epoch 1/16
# 1/5 [=====>........................]
#  - ETA: 3s - loss: 0.6761 - acc: 0.8798
#
# 5/5 [==============================]
#  - 1s 76ms/step - loss: 0.6931 - acc: 0.6166 - val_loss: 0.6991 - val_acc: 0.5024
#
# Epoch 2/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6512 - acc: 0.9821
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6820 - acc: 0.6934 - val_loss: 0.6988 - val_acc: 0.5059
#
# Epoch 3/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6406 - acc: 0.9966
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6792 - acc: 0.6518 - val_loss: 0.6986 - val_acc: 0.5255
#
# Epoch 4/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6322 - acc: 0.9982
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6776 - acc: 0.6412 - val_loss: 0.6986 - val_acc: 0.5231
#
# Epoch 5/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6247 - acc: 0.9998
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6765 - acc: 0.6350 - val_loss: 0.6986 - val_acc: 0.5232
#
# Epoch 6/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6181 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6758 - acc: 0.6315 - val_loss: 0.6988 - val_acc: 0.5228
#
# Epoch 7/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6125 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6754 - acc: 0.6292 - val_loss: 0.6990 - val_acc: 0.5234
#
# Epoch 8/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6074 - acc: 0.9998
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6752 - acc: 0.6279 - val_loss: 0.6992 - val_acc: 0.5238
#
# Epoch 9/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.6030 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6753 - acc: 0.6269 - val_loss: 0.6995 - val_acc: 0.5237
#
# Epoch 10/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5994 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6756 - acc: 0.6260 - val_loss: 0.6999 - val_acc: 0.5236
#
# Epoch 11/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5961 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6760 - acc: 0.6256 - val_loss: 0.7002 - val_acc: 0.5235
#
# Epoch 12/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5934 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6767 - acc: 0.6249 - val_loss: 0.7006 - val_acc: 0.5233
#
# Epoch 13/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5914 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6775 - acc: 0.6248 - val_loss: 0.7009 - val_acc: 0.5233
#
# Epoch 14/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5900 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6787 - acc: 0.6244 - val_loss: 0.7013 - val_acc: 0.5233
#
# Epoch 15/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5889 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 15ms/step - loss: 0.6799 - acc: 0.6244 - val_loss: 0.7017 - val_acc: 0.5232
#
# Epoch 16/16
# 1/5 [=====>........................]
#  - ETA: 0s - loss: 0.5885 - acc: 0.9999
#
# 5/5 [==============================]
#  - 0s 14ms/step - loss: 0.6812 - acc: 0.6242 - val_loss: 0.7021 - val_acc: 0.5232
#
# 100%|██████████| 5/5 [00:23<00:00,  4.63s/trial, best loss: -0.5420185923576355]
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6847 - acc: 0.5420

# %%
print(best_model.summary())
print(best_run)
print("val_loss: ", val_loss)
print("val_acc: ", val_acc)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128, 16)           1152
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128, 16)           0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128, 1)            17
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'Dropout': 0.41266207281071243, 'LSTM': 1, 'batch_size': 1, 'epochs': 1}
# val_loss:  0.6846697330474854
# val_acc:  0.5420185923576355

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (592, 128, 1) (592, 1) (592, 128, 1) (592, 1)
